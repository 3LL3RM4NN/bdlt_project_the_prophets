# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### load dataset

# %%
data = pd.read_csv('data/classified_data.csv', sep=',', header=0)
data['created_at'] = pd.to_datetime(data['created_at'])

# %%
data.head()
# Out:
#                  created_at        id         lng       lat  \
# 0 2007-03-27 14:27:38+00:00  13633131         NaN       NaN
# 1 2007-04-11 09:27:27+00:00  24477281   -2.716577  51.14804
# 2 2007-04-26 17:49:51+00:00  40935582 -122.332070  47.60621
# 3 2007-05-07 13:10:41+00:00  53214992         NaN       NaN
# 4 2007-05-22 16:38:15+00:00  74191762         NaN       NaN
#
#                           topic  sentiment    stance gender  temperature_avg  \
# 0              Weather Extremes   0.752387  believer   male              NaN
# 1  Seriousness of Gas Emissions   0.135546  believer   male         3.155858
# 2  Seriousness of Gas Emissions   0.072492  believer   male        -0.245944
# 3                 Global stance  -0.485976  believer   male              NaN
# 4                 Global stance  -0.180456   neutral   male              NaN
#
#    aggressiveness                                               text  \
# ...

# %%
data['topic_code'] = pd.factorize(data['topic'])[0]
data['gender_code'] = pd.factorize(data['gender'])[0]
data['stance_code'] = pd.factorize(data['stance'])[0]
data['aggressiveness_code'] = pd.factorize(data['aggressiveness'])[0]
data['label_code'] = pd.factorize(data['hf_label'])[0]

# %%
data.head()
# Out:
#                  created_at        id         lng       lat  \
# 0 2007-03-27 14:27:38+00:00  13633131         NaN       NaN
# 1 2007-04-11 09:27:27+00:00  24477281   -2.716577  51.14804
# 2 2007-04-26 17:49:51+00:00  40935582 -122.332070  47.60621
# 3 2007-05-07 13:10:41+00:00  53214992         NaN       NaN
# 4 2007-05-22 16:38:15+00:00  74191762         NaN       NaN
#
#                           topic  sentiment    stance gender  temperature_avg  \
# 0              Weather Extremes   0.752387  believer   male              NaN
# 1  Seriousness of Gas Emissions   0.135546  believer   male         3.155858
# 2  Seriousness of Gas Emissions   0.072492  believer   male        -0.245944
# 3                 Global stance  -0.485976  believer   male              NaN
# 4                 Global stance  -0.180456   neutral   male              NaN
#
#    aggressiveness                                               text  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68283 entries, 0 to 68282
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           68283 non-null  datetime64[ns, UTC]
#  1   id                   68283 non-null  int64
#  2   lng                  24797 non-null  float64
#  3   lat                  24797 non-null  float64
#  4   topic                68283 non-null  object
#  5   sentiment            68283 non-null  float64
#  6   stance               68283 non-null  object
#  7   gender               68283 non-null  object
#  8   temperature_avg      24797 non-null  float64
#  9   aggressiveness       68283 non-null  object
#  10  text                 68283 non-null  object
#  11  tb_polarity          68283 non-null  float64
#  12  tb_subjectivity      68283 non-null  float64
#  13  hf_label             68283 non-null  object
#  14  hf_score             68283 non-null  float64
# ...

# %%
data.corr()
# Out:
#                            id       lng       lat  sentiment  temperature_avg  \
# id                   1.000000  0.053515  0.002062   0.072136         0.137895
# lng                  0.053515  1.000000 -0.607683   0.055694        -0.006862
# lat                  0.002062 -0.607683  1.000000   0.001668         0.132806
# sentiment            0.072136  0.055694  0.001668   1.000000         0.027654
# temperature_avg      0.137895 -0.006862  0.132806   0.027654         1.000000
# tb_polarity          0.040647  0.017822 -0.005693   0.378311         0.022798
# tb_subjectivity      0.080491 -0.008507  0.003729  -0.002939         0.003472
# hf_score             0.029377  0.000322  0.006144   0.006041         0.011176
# topic_code           0.129992  0.047151  0.011365   0.094196         0.032752
# gender_code          0.019574  0.037178 -0.024020   0.016097         0.008372
# stance_code         -0.207586 -0.069261  0.003294  -0.142988        -0.056031
# ...

# %%
data.describe()
# Out:
#                  id           lng           lat     sentiment  \
# count  6.828300e+04  24797.000000  24797.000000  68283.000000
# mean   8.063511e+17    -43.507358     34.138373     -0.026242
# std    3.268015e+17     76.813557     23.332296      0.426249
# min    1.363313e+07   -161.755833    -76.050000     -0.978728
# 25%    6.757466e+17    -94.250550     33.749000     -0.404520
# 50%    9.439078e+17    -76.610759     40.349274     -0.037812
# 75%    1.037260e+18     -0.127647     47.166670      0.367817
# max    1.178898e+18    178.442166     79.994720      0.976721
#
#        temperature_avg   tb_polarity  tb_subjectivity      hf_score  \
# count     24797.000000  68283.000000     68283.000000  68283.000000
# mean          1.204358      0.045078         0.297883      0.729627
# std           3.771311      0.226309         0.276791      0.137312
# min         -18.063744     -1.000000         0.000000      0.338455
# ...

# %% [markdown]
# #### correlation plots

# %%
f = plt.figure(figsize=(10, 8))
plt.matshow(data.drop(['id', 'lng', 'lat'], axis=1).corr(), fignum=f.number)
plt.colorbar()

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = data.drop(['id', 'lng', 'lat'], axis=1).corr()
sns.heatmap(corr, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### gender stats
# as one can see, there are no noticeable differences for the value distributions throughout the gender

# %%
sns.boxplot(x='gender', y='sentiment', data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='sentiment'>

# %%
sns.boxplot(x='gender', y='temperature_avg', data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='temperature_avg'>

# %%
sns.boxplot(x='gender', y='tb_polarity', data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='tb_polarity'>

# %%
sns.boxplot(x='gender', y='tb_subjectivity', data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='tb_subjectivity'>

# %%
sns.boxplot(x='gender', y='hf_score', data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='hf_score'>

# %% [markdown]
# ### topic stats
# here the values seem to vary a bit from topic to topic

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(x='topic', y='sentiment', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='sentiment'>

# %%
sns.boxplot(x='topic', y='temperature_avg', data=data)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='temperature_avg'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(x='topic', y='tb_polarity', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='tb_polarity'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(x='topic', y='tb_subjectivity', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='tb_subjectivity'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(x='topic', y='hf_score', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='hf_score'>

# %% [markdown]
# ### stance stats
# in the case of the sentiment a difference between the stance can be seen

# %%
sns.boxplot(x='stance', y='sentiment', data=data)
# Out:
# <AxesSubplot:xlabel='stance', ylabel='sentiment'>

# %%
sns.boxplot(x='stance', y='temperature_avg', data=data)
# Out:
# <AxesSubplot:xlabel='stance', ylabel='temperature_avg'>

# %%
sns.boxplot(x='stance', y='tb_polarity', data=data)
# Out:
# <AxesSubplot:xlabel='stance', ylabel='tb_polarity'>

# %%
sns.boxplot(x='stance', y='tb_subjectivity', data=data)
# Out:
# <AxesSubplot:xlabel='stance', ylabel='tb_subjectivity'>

# %%
sns.boxplot(x='stance', y='hf_score', hue='hf_label', data=data)
# Out:
# <AxesSubplot:xlabel='stance', ylabel='hf_score'>

# %% [markdown]
# ### stats over time

# %% [markdown]
# #### monthly

# %%
data_month = data.copy()
data_month.index = data_month['created_at']
data_month = data_month.groupby(pd.Grouper(freq='M')).mean()

data_month.head(10)
# Out:
#                                      id         lng        lat  sentiment  \
# created_at
# 2007-03-31 00:00:00+00:00  1.363313e+07         NaN        NaN   0.752387
# 2007-04-30 00:00:00+00:00  3.270643e+07  -62.524324  49.377125   0.104019
# 2007-05-31 00:00:00+00:00  6.370338e+07         NaN        NaN  -0.333216
# 2007-06-30 00:00:00+00:00           NaN         NaN        NaN        NaN
# 2007-07-31 00:00:00+00:00  1.436029e+08  -83.000706  39.962260   0.383471
# 2007-08-31 00:00:00+00:00  1.891948e+08 -117.928950  33.618910  -0.027669
# 2007-09-30 00:00:00+00:00  2.900882e+08         NaN        NaN  -0.171306
# 2007-10-31 00:00:00+00:00  3.380847e+08  -86.774353  36.162230   0.247069
# 2007-11-30 00:00:00+00:00  4.354933e+08   -0.127647  51.507322  -0.315580
# 2007-12-31 00:00:00+00:00  4.871748e+08  -78.833620  35.651270   0.123308
#
#                            temperature_avg  tb_polarity  tb_subjectivity  \
# created_at
# ...

# %%
sns.relplot(x='created_at', y='sentiment', data=data_month, kind='line')

# %%
sns.relplot(x='created_at', y='tb_polarity', data=data_month, kind='line')

# %%
sns.relplot(x='created_at', y='tb_subjectivity', data=data_month, kind='line')

# %% [markdown]
# #### weekly

# %%
data_week = data.copy()
data_week.index = data_week['created_at']
data_week = data_week.groupby(pd.Grouper(freq='W')).mean()

data_week.tail(20)
# Out:
# created_at
# 2019-05-26 00:00:00+00:00    20
# 2019-06-02 00:00:00+00:00    16
# 2019-06-09 00:00:00+00:00    30
# 2019-06-16 00:00:00+00:00    15
# 2019-06-23 00:00:00+00:00     8
# 2019-06-30 00:00:00+00:00    13
# 2019-07-07 00:00:00+00:00     9
# 2019-07-14 00:00:00+00:00    11
# 2019-07-21 00:00:00+00:00    12
# 2019-07-28 00:00:00+00:00    17
# 2019-08-04 00:00:00+00:00    33
# 2019-08-11 00:00:00+00:00    22
# 2019-08-18 00:00:00+00:00    27
# 2019-08-25 00:00:00+00:00    39
# 2019-09-01 00:00:00+00:00    43
# 2019-09-08 00:00:00+00:00    37
# 2019-09-15 00:00:00+00:00    10
# 2019-09-22 00:00:00+00:00    20
# 2019-09-29 00:00:00+00:00    58
# 2019-10-06 00:00:00+00:00     6
# Freq: W-SUN, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.lineplot(x='created_at', y='tb_polarity', data=data_week, ax=ax)
sns.lineplot(x='created_at', y='tb_subjectivity', data=data_week, ax=ax)

plt.legend(['polarity', 'subjectivity'])
plt.xlabel('time')
plt.ylabel('sentiment_score')
# Out:
# Text(0, 0.5, 'sentiment_score')

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.lineplot(x='created_at', y='tb_polarity', data=data_week, ax=ax)
# Out:
# <AxesSubplot:xlabel='created_at', ylabel='tb_polarity'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.lineplot(x='created_at', y='tb_subjectivity', data=data_week, ax=ax)
# Out:
# <AxesSubplot:xlabel='created_at', ylabel='tb_subjectivity'>

# %%
data_week = data.copy()
data_week.index = data_week['created_at']
data_week = data_week.groupby(pd.Grouper(freq='W')).size()

data_week.plot.line()
# Out:
# <AxesSubplot:xlabel='created_at'>

# %% [markdown]
# ### huggingface twitter roberta

# %%
# confidence of class
sns.boxplot(data=data, x='hf_label', y='hf_score')
# Out:
# <AxesSubplot:xlabel='hf_label', ylabel='hf_score'>

# %%
sns.boxplot(data=data, x='hf_label', y='hf_score', hue='gender')
# Out:
# <AxesSubplot:xlabel='hf_label', ylabel='hf_score'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(data=data, x='hf_label', y='hf_score', hue='stance', ax=ax)
# Out:
# <AxesSubplot:xlabel='hf_label', ylabel='hf_score'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(data=data, x='hf_label', y='hf_score', hue='topic', ax=ax)
# Out:
# <AxesSubplot:xlabel='hf_label', ylabel='hf_score'>

# %%
sns.boxplot(data=data, x='hf_label', y='hf_score', hue='aggressiveness')
# Out:
# <AxesSubplot:xlabel='hf_label', ylabel='hf_score'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.lineplot(x='created_at', y='hf_score', hue='hf_label', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='created_at', ylabel='hf_score'>

# %%
sns.relplot(x='tb_polarity', y='hf_score', col='hf_label', data=data)

# %% [markdown]
# ### textblob

# %%
sns.relplot(x='tb_polarity', y='tb_subjectivity', hue='stance', col='hf_label', data=data)

# %%
sns.relplot(x='tb_polarity', y='tb_subjectivity', hue='hf_label', col='stance', data=data)

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(x='topic', y='tb_subjectivity', hue='aggressiveness', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='tb_subjectivity'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxplot(x='topic', y='tb_subjectivity', hue='stance', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='tb_subjectivity'>

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.boxenplot(x='topic', y='tb_polarity', hue='stance', data=data, ax=ax)
# Out:
# <AxesSubplot:xlabel='topic', ylabel='tb_polarity'>

# %% [markdown]
# ### topic count for different data stages

# %%
names_topic_dist = ['Weather Extremes', 'Global stance', 'Importance of Human Intervantion', 'Seriousness of Gas Emissions', 'Donald Trump versus Science',
                    'Politics', 'Ideological Positions on Global Warming', 'Undefined / One Word Hashtags', 'Impact of Resource Overconsumption', 'Significance of Pollution Awareness Events']
original_topic_dist = [2464814, 4135619, 2594941, 903478, 996244, 1809583, 602695, 1305118, 496924, 479995]
sampled_dopic_dist = [294710, 518997, 320291, 108138, 120519, 222817, 71593, 167454, 58958, 58961]
statement_topic_dist = [17095, 36494, 15182, 5824, 7851, 12404, 1441, 7263, 2634, 3059]
classified_topic_dist = [13177, 21577, 8062, 4146, 4567, 5755, 1091, 5993, 1851, 2064]

topic_dict = {
    'original': original_topic_dist,
    'sampled': sampled_dopic_dist,
    'statement': statement_topic_dist,
    'deduplicated': classified_topic_dist
}

topic_data = pd.DataFrame.from_dict(topic_dict, 'index')
topic_data.columns = names_topic_dist

topic_data.head()
# Out:
#               Weather Extremes  Global stance  \
# original               2464814        4135619
# sampled                 294710         518997
# statement                17095          36494
# deduplicated             13177          21577
#
#               Importance of Human Intervantion  Seriousness of Gas Emissions  \
# original                               2594941                        903478
# sampled                                 320291                        108138
# statement                                15182                          5824
# deduplicated                              8062                          4146
#
#               Donald Trump versus Science  Politics  \
# original                           996244   1809583
# sampled                            120519    222817
# statement                            7851     12404
# deduplicated                         4567      5755
#
#               Ideological Positions on Global Warming  \
# ...

# %%
topic_data_percent = topic_data.div(topic_data.sum(axis=1), axis=0)

ax = topic_data_percent.T.plot.barh(figsize=(15,7))
ax.figure.savefig('plots/topic_dist.png', bbox_inches='tight')
